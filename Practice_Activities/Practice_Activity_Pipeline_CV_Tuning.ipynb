# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
ames = pd.read_csv("/Users/AustinLiu/Desktop/GSB544-ComputingandMachineLearning/In-Class-Data/AmesHousing.csv")
ames.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0        0       5    2010       WD           Normal     215000
# 1        0       6    2010       WD           Normal     105000
# 2    12500       6    2010       WD           Normal     172000
# 3        0       4    2010       WD           Normal     244000
# 4        0       3    2010       WD           Normal     189900
#
# [5 rows x 82 columns]

# %%
# Get rid of columns with mostly NaN values
good_cols = ames.isna().sum() < 100
ames = ames.loc[:,good_cols]

# Drop other NAs
ames = ames.dropna()
ames
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Area Street Lot Shape  \
# 0         1  526301100           20        RL     31770   Pave       IR1
# 1         2  526350040           20        RH     11622   Pave       Reg
# 2         3  526351010           20        RL     14267   Pave       IR1
# 3         4  526353030           20        RL     11160   Pave       Reg
# 4         5  527105010           60        RL     13830   Pave       IR1
# ...     ...        ...          ...       ...       ...    ...       ...
# 2925   2926  923275080           80        RL      7937   Pave       IR1
# 2926   2927  923276100           20        RL      8885   Pave       IR1
# 2927   2928  923400125           85        RL     10441   Pave       Reg
# 2928   2929  924100070           20        RL     10010   Pave       Reg
# 2929   2930  924151050           60        RL      9627   Pave       Reg
#
#      Land Contour Utilities Lot Config  ... Enclosed Porch 3Ssn Porch  \
# 0             Lvl    AllPub     Corner  ...              0          0
# 1             Lvl    AllPub     Inside  ...              0          0
# 2             Lvl    AllPub     Corner  ...              0          0
# 3             Lvl    AllPub     Corner  ...              0          0
# 4             Lvl    AllPub     Inside  ...              0          0
# ...           ...       ...        ...  ...            ...        ...
# 2925          Lvl    AllPub    CulDSac  ...              0          0
# 2926          Low    AllPub     Inside  ...              0          0
# 2927          Lvl    AllPub     Inside  ...              0          0
# 2928          Lvl    AllPub     Inside  ...              0          0
# 2929          Lvl    AllPub     Inside  ...              0          0
#
#      Screen Porch Pool Area Misc Val Mo Sold  Yr Sold  Sale Type  \
# 0               0         0        0       5     2010        WD
# 1             120         0        0       6     2010        WD
# 2               0         0    12500       6     2010        WD
# 3               0         0        0       4     2010        WD
# 4               0         0        0       3     2010        WD
# ...           ...       ...      ...     ...      ...        ...
# 2925            0         0        0       3     2006        WD
# 2926            0         0        0       6     2006        WD
# 2927            0         0      700       7     2006        WD
# 2928            0         0        0       4     2006        WD
# 2929            0         0        0      11     2006        WD
#
#       Sale Condition  SalePrice
# 0             Normal     215000
# 1             Normal     105000
# 2             Normal     172000
# 3             Normal     244000
# 4             Normal     189900
# ...              ...        ...
# 2925          Normal     142500
# 2926          Normal     131000
# 2927          Normal     132000
# 2928          Normal     170000
# 2929          Normal     188000
#
# [2821 rows x 71 columns]

# %% [markdown]
# # Part 1

# %%
X = ames.drop('SalePrice', axis=1)
y = ames['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
# Pipeline 1
lr = LinearRegression()
std_s = StandardScaler()

ct = ColumnTransformer(
    [("standardize", std_s, ["Gr Liv Area", "TotRms AbvGrd"])],
    remainder = "drop" 
)

lr_pipeline = Pipeline(
  [("standardize", ct),
  ("linear_regression", lr)]
)

lr_pipeline_fitted = lr_pipeline.fit(X_train, y_train)
y_preds = lr_pipeline_fitted.predict(X_test)

rmse1 = mean_squared_error(y_test, y_preds, squared = False)
rmse1
# Out:
# 55659.17989912858

# %%
# Pipeline 2
enc = OneHotEncoder(sparse_output = False)

ct = ColumnTransformer(
    [("standardize", std_s, ["Gr Liv Area", "TotRms AbvGrd"]),
     ("dummify", enc, ["Bldg Type"])],
    remainder = "drop" 
)

lr_pipeline2 = Pipeline(
  [("preprocessing", ct),
  ("linear_regression", lr)]
)

lr_pipeline_fitted2 = lr_pipeline2.fit(X_train, y_train)
y_preds2 = lr_pipeline_fitted2.predict(X_test)

rmse2 = mean_squared_error(y_test, y_preds2, squared = False)
rmse2
# Out:
# 54456.27691201109

# %%
# Pipeline 3

enc = OneHotEncoder(sparse_output = False)

ct_dummy = ColumnTransformer(
    [("dummify", enc, ["Bldg Type"])], remainder = "passthrough"
).set_output(transform = "pandas")

ct_dummy.fit_transform(X_train)

ct_interact = ColumnTransformer(
    [("interaction", PolynomialFeatures(interaction_only = True), ["remainder__Gr Liv Area", "dummify__Bldg Type_1Fam"]),
    ("interaction2", PolynomialFeatures(interaction_only = True), ["remainder__Gr Liv Area", "dummify__Bldg Type_2fmCon"]),
    ("interaction3", PolynomialFeatures(interaction_only = True), ["remainder__Gr Liv Area", "dummify__Bldg Type_Duplex"]),
    ("interaction4", PolynomialFeatures(interaction_only = True), ["remainder__Gr Liv Area", "dummify__Bldg Type_Twnhs"]),
    ("interaction5", PolynomialFeatures(interaction_only = True), ["remainder__Gr Liv Area", "dummify__Bldg Type_TwnhsE"])],
).set_output(transform = "pandas")

lr_pipeline_inter = Pipeline(
    [("dummify", ct_dummy),
     ("interacting", ct_interact),
      ("linear regression", lr)]
).set_output(transform = "pandas")


lr_pipeline_fitted3 = lr_pipeline_inter.fit(X_train, y_train)
y_preds3 = lr_pipeline_fitted3.predict(X_test)

rmse3 = mean_squared_error(y_test, y_preds3, squared = False)
rmse3
# Out:
# 54076.09217134571

# %%
# Pipeline 4

enc = OneHotEncoder(sparse_output = False)

ct_preprocess = ColumnTransformer(
    [("dummify", enc, ["Bldg Type"]),
     ("polynomial", PolynomialFeatures(degree = 5), ["Gr Liv Area", "TotRms AbvGrd"])], remainder = "drop"
).set_output(transform = "pandas")

ct_preprocess.fit_transform(X_train)

lr_pipeline_poly = Pipeline(
    [("preprocessing", ct_preprocess),
      ("linear regression", lr)]
).set_output(transform = "pandas")

lr_pipeline_fitted4 = lr_pipeline_poly.fit(X_train, y_train) 
y_preds4 = lr_pipeline_fitted4.predict(X_test)

rmse4 = mean_squared_error(y_test, y_preds4, squared = False)
rmse4
# Out:
# 113618.49579087284

# %% [markdown]
# Best RMSE was Model 3, 54076.

# %% [markdown]
# # Part 2 Cross_Val_Score

# %%
score1 = cross_val_score(lr_pipeline, X, y, cv=5, scoring='neg_root_mean_squared_error')
-score1.mean()
# Out:
# 55483.717958704314

# %%
score2 = cross_val_score(lr_pipeline2, X, y, cv=5, scoring='neg_root_mean_squared_error')
-score2.mean()
# Out:
# 54107.50773455426

# %%
score3 = cross_val_score(lr_pipeline_inter, X, y, cv=5, scoring='neg_root_mean_squared_error')
-score3.mean()
# Out:
# 53324.75612669396

# %%
score4 = cross_val_score(lr_pipeline_poly, X, y, cv=5, scoring='neg_root_mean_squared_error')
-score4.mean()
# Out:
# 58902.911810473175

# %% [markdown]
# Model 3 still had the best.

# %% [markdown]
# # Part 3

# %%
ct_tuning = ColumnTransformer(
  [("size_polynomial", PolynomialFeatures(), ["Gr Liv Area"]),
  ("rooms_polynomial", PolynomialFeatures(), ["TotRms AbvGrd"]),
   ("dummify", OneHotEncoder(sparse_output = False), ["Bldg Type"])],
  remainder = "drop"
)

lr_pipeline_tuning = Pipeline(
  [("preprocessing", ct_tuning),
  ("linear_regression", lr)]
).set_output(transform="pandas")

degrees = {'preprocessing__size_polynomial__degree': np.arange(1, 11),
           "preprocessing__rooms_polynomial__degree": np.arange(1, 11)}

gscv = GridSearchCV(lr_pipeline_tuning, degrees, cv = 5, scoring='r2')

gscv_fitted = gscv.fit(X, y)

gscv_fitted.cv_results_
# Out:
# {'mean_fit_time': array([0.00697026, 0.00398431, 0.00362024, 0.00364566, 0.00370445,
#         0.00372305, 0.00377741, 0.00379524, 0.00436339, 0.00635738,
#         0.00483575, 0.00539465, 0.00540013, 0.00503063, 0.00579901,
#         0.00667324, 0.00380645, 0.00555258, 0.00809798, 0.00705881,
#         0.00570874, 0.00521059, 0.00438414, 0.00524235, 0.00506496,
#         0.00546861, 0.00514212, 0.00544734, 0.00605974, 0.00821953,
#         0.0062561 , 0.00483413, 0.00759377, 0.00530825, 0.00568347,
#         0.00572896, 0.00535688, 0.00619941, 0.0052762 , 0.0061595 ,
#         0.00620265, 0.00448532, 0.00486751, 0.00386553, 0.006949  ,
#         0.00550823, 0.00738592, 0.00737309, 0.00761728, 0.00727921,
#         0.00605106, 0.005793  , 0.00625052, 0.00502234, 0.00690107,
#         0.00505962, 0.00687861, 0.00709839, 0.0055419 , 0.00625567,
#         0.00456672, 0.0052505 , 0.00558958, 0.00640583, 0.00643249,
#         0.00528979, 0.00539827, 0.0055449 , 0.00811195, 0.00717397,
#         0.00817895, 0.00720263, 0.00600863, 0.00573215, 0.00517039,
#         0.00525322, 0.00657172, 0.00509377, 0.00688725, 0.0051281 ,
#         0.00575948, 0.00577044, 0.00537534, 0.00547824, 0.00622749,
#         0.00506787, 0.00567994, 0.00680537, 0.00512466, 0.00617104,
#         0.00595217, 0.00576901, 0.00540605, 0.00513039, 0.00668373,
#         0.00684462, 0.00566649, 0.00503607, 0.00648932, 0.00726056]),
#  'std_fit_time': array([2.04490241e-03, 3.84712698e-04, 3.02495211e-05, 1.36161850e-05,
#         2.58424624e-05, 5.85869696e-06, 3.22154939e-05, 1.76903372e-05,
, 2, 3, 4, 5, 6, 7, 8, 9, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'preprocessing__rooms_polynomial__degree': 1,
#    'preprocessing__size_polynomial__degree': 1},
#   {'preprocessing__rooms_polynomial__degree': 1,
#    'preprocessing__size_polynomial__degree': 2},
#   {'preprocessing__rooms_polynomial__degree': 1,
#    'preprocessing__size_polynomial__degree': 3},
#   {'preprocessing__rooms_polynomial__degree': 1,
#    'preprocessing__size_polynomial__degree': 4},
#   {'preprocessing__rooms_polynomial__degree': 1,
#    'preprocessing__size_polynomial__degree': 5},
#   {'preprocessing__rooms_polynomial__degree': 1,
#    'preprocessing__size_polynomial__degree': 6},
#   {'preprocessing__rooms_polynomial__degree': 1,
#    'preprocessing__size_polynomial__degree': 7},
#   {'preprocessing__rooms_polynomial__degree': 1,
#    'preprocessing__size_polynomial__degree': 8},
#   {'preprocessing__rooms_polynomial__degree': 1,
#    'preprocessing__size_polynomial__degree': 9},
#   {'preprocessing__rooms_polynomial__degree': 1,
#    'preprocessing__size_polynomial__degree': 10},
#   {'preprocessing__rooms_polynomial__degree': 2,
#    'preprocessing__size_polynomial__degree': 1},
#   {'preprocessing__rooms_polynomial__degree': 2,
#    'preprocessing__size_polynomial__degree': 2},
#   {'preprocessing__rooms_polynomial__degree': 2,
#    'preprocessing__size_polynomial__degree': 3},
#   {'preprocessing__rooms_polynomial__degree': 2,
#    'preprocessing__size_polynomial__degree': 4},
#   {'preprocessing__rooms_polynomial__degree': 2,
#    'preprocessing__size_polynomial__degree': 5},
#   {'preprocessing__rooms_polynomial__degree': 2,
#    'preprocessing__size_polynomial__degree': 6},
#   {'preprocessing__rooms_polynomial__degree': 2,
#    'preprocessing__size_polynomial__degree': 7},
#   {'preprocessing__rooms_polynomial__degree': 2,
#    'preprocessing__size_polynomial__degree': 8},
#   {'preprocessing__rooms_polynomial__degree': 2,
#    'preprocessing__size_polynomial__degree': 9},
#   {'preprocessing__rooms_polynomial__degree': 2,
#    'preprocessing__size_polynomial__degree': 10},
#   {'preprocessing__rooms_polynomial__degree': 3,
#    'preprocessing__size_polynomial__degree': 1},
#   {'preprocessing__rooms_polynomial__degree': 3,
#    'preprocessing__size_polynomial__degree': 2},
#   {'preprocessing__rooms_polynomial__degree': 3,
#    'preprocessing__size_polynomial__degree': 3},
#   {'preprocessing__rooms_polynomial__degree': 3,
#    'preprocessing__size_polynomial__degree': 4},
#   {'preprocessing__rooms_polynomial__degree': 3,
#    'preprocessing__size_polynomial__degree': 5},
#   {'preprocessing__rooms_polynomial__degree': 3,
#    'preprocessing__size_polynomial__degree': 6},
#   {'preprocessing__rooms_polynomial__degree': 3,
#    'preprocessing__size_polynomial__degree': 7},
#   {'preprocessing__rooms_polynomial__degree': 3,
#    'preprocessing__size_polynomial__degree': 8},
#   {'preprocessing__rooms_polynomial__degree': 3,
#    'preprocessing__size_polynomial__degree': 9},
#   {'preprocessing__rooms_polynomial__degree': 3,
#    'preprocessing__size_polynomial__degree': 10},
#   {'preprocessing__rooms_polynomial__degree': 4,
#    'preprocessing__size_polynomial__degree': 1},
#   {'preprocessing__rooms_polynomial__degree': 4,
#    'preprocessing__size_polynomial__degree': 2},
#   {'preprocessing__rooms_polynomial__degree': 4,
#    'preprocessing__size_polynomial__degree': 3},
#   {'preprocessing__rooms_polynomial__degree': 4,
#    'preprocessing__size_polynomial__degree': 4},
#   {'preprocessing__rooms_polynomial__degree': 4,
#    'preprocessing__size_polynomial__degree': 5},
#   {'preprocessing__rooms_polynomial__degree': 4,
#    'preprocessing__size_polynomial__degree': 6},
#   {'preprocessing__rooms_polynomial__degree': 4,
#    'preprocessing__size_polynomial__degree': 7},
#   {'preprocessing__rooms_polynomial__degree': 4,
#    'preprocessing__size_polynomial__degree': 8},
#   {'preprocessing__rooms_polynomial__degree': 4,
#    'preprocessing__size_polynomial__degree': 9},
#   {'preprocessing__rooms_polynomial__degree': 4,
#    'preprocessing__size_polynomial__degree': 10},
#   {'preprocessing__rooms_polynomial__degree': 5,
#    'preprocessing__size_polynomial__degree': 1},
#   {'preprocessing__rooms_polynomial__degree': 5,
#    'preprocessing__size_polynomial__degree': 2},
#   {'preprocessing__rooms_polynomial__degree': 5,
#    'preprocessing__size_polynomial__degree': 3},
#   {'preprocessing__rooms_polynomial__degree': 5,
#    'preprocessing__size_polynomial__degree': 4},
#   {'preprocessing__rooms_polynomial__degree': 5,
#    'preprocessing__size_polynomial__degree': 5},
#   {'preprocessing__rooms_polynomial__degree': 5,
#    'preprocessing__size_polynomial__degree': 6},
#   {'preprocessing__rooms_polynomial__degree': 5,
#    'preprocessing__size_polynomial__degree': 7},
#   {'preprocessing__rooms_polynomial__degree': 5,
#    'preprocessing__size_polynomial__degree': 8},
#   {'preprocessing__rooms_polynomial__degree': 5,
#    'preprocessing__size_polynomial__degree': 9},
#   {'preprocessing__rooms_polynomial__degree': 5,
#    'preprocessing__size_polynomial__degree': 10},
#   {'preprocessing__rooms_polynomial__degree': 6,
#    'preprocessing__size_polynomial__degree': 1},
#   {'preprocessing__rooms_polynomial__degree': 6,
#    'preprocessing__size_polynomial__degree': 2},
#   {'preprocessing__rooms_polynomial__degree': 6,
#    'preprocessing__size_polynomial__degree': 3},
#   {'preprocessing__rooms_polynomial__degree': 6,
#    'preprocessing__size_polynomial__degree': 4},
#   {'preprocessing__rooms_polynomial__degree': 6,
#    'preprocessing__size_polynomial__degree': 5},
#   {'preprocessing__rooms_polynomial__degree': 6,
#    'preprocessing__size_polynomial__degree': 6},
#   {'preprocessing__rooms_polynomial__degree': 6,
#    'preprocessing__size_polynomial__degree': 7},
#   {'preprocessing__rooms_polynomial__degree': 6,
#    'preprocessing__size_polynomial__degree': 8},
#   {'preprocessing__rooms_polynomial__degree': 6,
#    'preprocessing__size_polynomial__degree': 9},
#   {'preprocessing__rooms_polynomial__degree': 6,
#    'preprocessing__size_polynomial__degree': 10},
#   {'preprocessing__rooms_polynomial__degree': 7,
#    'preprocessing__size_polynomial__degree': 1},
#   {'preprocessing__rooms_polynomial__degree': 7,
#    'preprocessing__size_polynomial__degree': 2},
#   {'preprocessing__rooms_polynomial__degree': 7,
#    'preprocessing__size_polynomial__degree': 3},
#   {'preprocessing__rooms_polynomial__degree': 7,
#    'preprocessing__size_polynomial__degree': 4},
#   {'preprocessing__rooms_polynomial__degree': 7,
#    'preprocessing__size_polynomial__degree': 5},
#   {'preprocessing__rooms_polynomial__degree': 7,
#    'preprocessing__size_polynomial__degree': 6},
#   {'preprocessing__rooms_polynomial__degree': 7,
#    'preprocessing__size_polynomial__degree': 7},
#   {'preprocessing__rooms_polynomial__degree': 7,
#    'preprocessing__size_polynomial__degree': 8},
#   {'preprocessing__rooms_polynomial__degree': 7,
#    'preprocessing__size_polynomial__degree': 9},
#   {'preprocessing__rooms_polynomial__degree': 7,
#    'preprocessing__size_polynomial__degree': 10},
#   {'preprocessing__rooms_polynomial__degree': 8,
#    'preprocessing__size_polynomial__degree': 1},
#   {'preprocessing__rooms_polynomial__degree': 8,
#    'preprocessing__size_polynomial__degree': 2},
#   {'preprocessing__rooms_polynomial__degree': 8,
#    'preprocessing__size_polynomial__degree': 3},
#   {'preprocessing__rooms_polynomial__degree': 8,
#    'preprocessing__size_polynomial__degree': 4},
#   {'preprocessing__rooms_polynomial__degree': 8,
#    'preprocessing__size_polynomial__degree': 5},
#   {'preprocessing__rooms_polynomial__degree': 8,
#    'preprocessing__size_polynomial__degree': 6},
#   {'preprocessing__rooms_polynomial__degree': 8,
#    'preprocessing__size_polynomial__degree': 7},
#   {'preprocessing__rooms_polynomial__degree': 8,
#    'preprocessing__size_polynomial__degree': 8},
#   {'preprocessing__rooms_polynomial__degree': 8,
#    'preprocessing__size_polynomial__degree': 9},
#   {'preprocessing__rooms_polynomial__degree': 8,
#    'preprocessing__size_polynomial__degree': 10},
#   {'preprocessing__rooms_polynomial__degree': 9,
#    'preprocessing__size_polynomial__degree': 1},
#   {'preprocessing__rooms_polynomial__degree': 9,
#    'preprocessing__size_polynomial__degree': 2},
#   {'preprocessing__rooms_polynomial__degree': 9,
#    'preprocessing__size_polynomial__degree': 3},
#   {'preprocessing__rooms_polynomial__degree': 9,
#    'preprocessing__size_polynomial__degree': 4},
#   {'preprocessing__rooms_polynomial__degree': 9,
#    'preprocessing__size_polynomial__degree': 5},
#   {'preprocessing__rooms_polynomial__degree': 9,
#    'preprocessing__size_polynomial__degree': 6},
#   {'preprocessing__rooms_polynomial__degree': 9,
#    'preprocessing__size_polynomial__degree': 7},
#   {'preprocessing__rooms_polynomial__degree': 9,
#    'preprocessing__size_polynomial__degree': 8},
#   {'preprocessing__rooms_polynomial__degree': 9,
#    'preprocessing__size_polynomial__degree': 9},
#   {'preprocessing__rooms_polynomial__degree': 9,
#    'preprocessing__size_polynomial__degree': 10},
#   {'preprocessing__rooms_polynomial__degree': 10,
#    'preprocessing__size_polynomial__degree': 1},
#   {'preprocessing__rooms_polynomial__degree': 10,
#    'preprocessing__size_polynomial__degree': 2},
#   {'preprocessing__rooms_polynomial__degree': 10,
#    'preprocessing__size_polynomial__degree': 3},
#   {'preprocessing__rooms_polynomial__degree': 10,
#    'preprocessing__size_polynomial__degree': 4},
#   {'preprocessing__rooms_polynomial__degree': 10,
#         5.93509050e-02, 5.65857781e-02, 3.89729088e-02, 4.77959461e-02,
#         8.79797030e-02, 3.48777339e-01, 8.24653350e-01, 2.37312645e+00,
#         1.08225167e+01, 5.13064204e+01, 7.18289202e-02, 7.06520145e-02,
#         5.17964819e-02, 4.53422628e-02, 8.86007472e-02, 3.48777339e-01,
#         8.24653350e-01, 2.37312645e+00, 1.08225167e+01, 5.13064204e+01,
#         7.21460986e-02, 6.96444158e-02, 5.17539125e-02, 4.58566097e-02,
#         8.60593180e-02, 3.48777340e-01, 8.24653350e-01, 2.37312645e+00,
#         1.08225167e+01, 5.13064204e+01, 7.11809867e-02, 7.25722910e-02,
#         4.39376231e-02, 4.15371606e-02, 5.84848299e-02, 1.12442585e-01,
#         8.24653350e-01, 2.37312645e+00, 1.08225167e+01, 5.13064204e+01,
#         9.03407947e-01, 3.30881367e-01, 1.81953439e-01, 5.06505539e-02,
#         4.95650287e-02, 9.82385236e-02, 8.24653350e-01, 2.37312645e+00,
#         1.08225167e+01, 5.13064204e+01, 4.24913513e+00, 1.76754248e+00,
#         3.63398887e-01, 4.33548325e-02, 1.39363281e-01, 2.88325543e-01,
#         8.24653314e-01, 2.37312645e+00, 1.08225167e+01, 5.13064204e+01,
#         2.50765497e+00, 3.75532741e-01, 2.10077580e+00, 1.39345178e+00,
#         2.46043443e-01, 3.34338333e-01, 2.58200235e-01, 2.37312645e+00,
#         1.08225167e+01, 5.13065257e+01, 2.43858606e+02, 2.98255134e+02,
#         6.83980714e+02, 7.47782918e-01, 2.64232925e-01, 5.45812359e-01,
#         2.23429040e-01, 2.37312645e+00, 1.08225204e+01, 5.13065257e+01]),
#  'rank_test_score': array([ 23,  17,   3,  11,  34,  48,  56,  67,  80,  94,  26,  24,   4,
#           9,  35,  47,  60,  74,  79,  92,  18,  22,   6,   8,  29,  46,
#          57,  73,  85,  91,  13,  19,  10,   2,  30,  45,  61,  68,  84,
#          90,  14,  27,  12,   1,  31,  44,  58,  72,  86,  95,  16,  21,
#          15,   7,  25,  33,  59,  69,  83,  89,  54,  42,  37,   5,  28,
#          32,  62,  70,  78,  93,  77,  64,  41,  20,  36,  43,  55,  71,
#          82,  88,  66,  49,  65,  63,  38,  50,  51,  75,  81,  96,  98,
#          99, 100,  52,  39,  53,  40,  76,  87,  96], dtype=int32)}

# %%
gscv_df = pd.DataFrame(gscv_fitted.cv_results_)
gscv_df = gscv_df[["param_preprocessing__rooms_polynomial__degree",
                   "param_preprocessing__size_polynomial__degree",
                   "mean_test_score"]]
gscv_df.rename(columns = {
    "param_preprocessing__rooms_polynomial__degree" : "room degree",
    "param_preprocessing__size_polynomial__degree" : "size degree",
    "mean_test_score": "r2"
}, inplace = True)

gscv_df.sort_values(by = "r2", ascending = False).head()
# Out:
#    room degree size degree        r2
# 43           5           4  0.559322
# 33           4           4  0.559221
# 2            1           3  0.558259
# 12           2           3  0.557383
# 63           7           4  0.555882

# %% [markdown]
# The best model was a polynomial with 5th degree room and 4th degree for the size
